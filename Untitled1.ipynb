# %%
# Компаративный анализ алгоритмов K-means
## Эксперимент на синтетических данных

**Цель:** Сравнить три алгоритма кластеризации:
1. Classic K-means
2. K-means++
3. Mini-Batch K-means

**Датасеты:**
- Четкие кластеры (blobs)
- Перекрывающиеся кластеры
- Данные в форме "лун"

**Метрики:**
- Время выполнения
- Инерция (within-cluster sum of squares)
- Стабильность
# Out:
#   Cell In[1], line 4
#     **Цель:** Сравнить три алгоритма кластеризации:
#     ^
# SyntaxError: invalid syntax
